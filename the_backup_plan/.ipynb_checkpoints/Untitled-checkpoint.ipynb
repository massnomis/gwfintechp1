# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %%
magic_dataframe_path = Path("magic_dataframe.csv")
magic_dataframe_df = pd.read_csv(magic_dataframe_path, index_col="Date", parse_dates=True, infer_datetime_format=True)

magic_dataframe_df.head()
# Out:
#             Symbol           USD  priceInETH  Deposit Rate  aIncentivesAPY  \
# Date
# 2021-04-01  WMATIC      0.362897         NaN      0.023412        0.057098
# 2021-04-01    WBTC  58597.095529         NaN      0.020301        0.044710
# 2021-04-01    USDC      0.999563         NaN      0.017828        0.032457
# 2021-04-01    WETH   1975.812277         NaN      0.013582        0.021319
# 2021-04-01     DAI      0.999956         NaN      0.037586        0.055193
#
#             vIncentivesAPY  totalLiquidity  utilizationRate  \
# Date
# 2021-04-01        0.132492    3.902638e+08         0.430954
# 2021-04-01        0.098943    2.670075e+04         0.451873
# 2021-04-01        0.048696    1.383281e+09         0.666525
# 2021-04-01        0.061145    7.820584e+05         0.348662
# 2021-04-01        0.068840    8.155841e+08         0.801760
#
#             vEmissionPerSecond  totalVariableDebt  \
# Date
# 2021-04-01  706597222222222222       1.681859e+08
# ...

# %%
magic_dataframe_df.shape
# Out:
# (413, 18)

# %%
magic_dataframe_df.count()
# Out:
# Symbol                              413
# USD                                 413
# priceInETH                            0
# Deposit Rate                        413
# aIncentivesAPY                      413
# vIncentivesAPY                      413
# totalLiquidity                      413
# utilizationRate                     413
# vEmissionPerSecond                  413
# totalVariableDebt                   413
# lifetimeDepositorsInterestEarned    413
# availableLiquidity                  413
# aEmissionPerSecond                  413
# totalLiquidityNormalized            413
# totalBorrowsNormalized              413
# totalBorrowsVariableNormalized      413
# availableLiquidityNormalized        413
# Price in ETH                        413
# dtype: int64

# %%
magic_dataframe_df.dropna(0).count()
# Out:
# Symbol                              0
# USD                                 0
# priceInETH                          0
# Deposit Rate                        0
# aIncentivesAPY                      0
# vIncentivesAPY                      0
# totalLiquidity                      0
# utilizationRate                     0
# vEmissionPerSecond                  0
# totalVariableDebt                   0
# lifetimeDepositorsInterestEarned    0
# availableLiquidity                  0
# aEmissionPerSecond                  0
# totalLiquidityNormalized            0
# totalBorrowsNormalized              0
# totalBorrowsVariableNormalized      0
# availableLiquidityNormalized        0
# Price in ETH                        0
# dtype: int64

# %%
magic_dataframe_df.head()
# Out:
#             Symbol           USD  priceInETH  Deposit Rate  aIncentivesAPY  \
# Date
# 2021-04-01  WMATIC      0.362897         NaN      0.023412        0.057098
# 2021-04-01    WBTC  58597.095529         NaN      0.020301        0.044710
# 2021-04-01    USDC      0.999563         NaN      0.017828        0.032457
# 2021-04-01    WETH   1975.812277         NaN      0.013582        0.021319
# 2021-04-01     DAI      0.999956         NaN      0.037586        0.055193
#
#             vIncentivesAPY  totalLiquidity  utilizationRate  \
# Date
# 2021-04-01        0.132492    3.902638e+08         0.430954
# 2021-04-01        0.098943    2.670075e+04         0.451873
# 2021-04-01        0.048696    1.383281e+09         0.666525
# 2021-04-01        0.061145    7.820584e+05         0.348662
# 2021-04-01        0.068840    8.155841e+08         0.801760
#
#             vEmissionPerSecond  totalVariableDebt  \
# Date
# 2021-04-01  706597222222222222       1.681859e+08
# ...
