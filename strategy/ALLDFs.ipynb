# %%
#ALLDFs
import requests
import json
import pandas as pd
from datetime import datetime, timedelta
import time
import csv
# %%
base_url = 'https://aave-api-v2.aave.com/data/liquidity/v2?poolId=' # This is the base API URL
pool_id = '0xd05e3e715d945b59290df0ae8ef85c1bdb684744' # This is the Pool ID for the Matic Network
# %%
range_of_dates = pd.date_range(start = "2021-04-01",end = (datetime.today() - timedelta(days = 1))).date # List of dates from the start of the AAVE API to yesterday
list_of_dates = []
for date in range_of_dates: # For each date in the list of dates
    list_of_dates.append(date.strftime("%m-%d-%Y")) # Format it correctly for use in the API and append it to a new list
# %%
col_names = ['Date','Symbol', 'USD', 'priceInETH', 'Deposit Rate', 'aIncentivesAPY',
             'vIncentivesAPY','totalLiquidity','utilizationRate','vEmissionPerSecond','totalVariableDebt',
             'lifetimeDepositorsInterestEarned','availableLiquidity','aEmissionPerSecond','totalLiquidityNormalized',
             'totalBorrowsNormalized','totalBorrowsVariableNormalized', 'availableLiquidityNormalized'] 
# These are the fields we want

## totalLiquidity X 
## utilizationRate X
## vEmissionPerSecond X
## totalVariableDebt X
## lifetimeDepositorsInterestEarned X
## availableLiquidity X
## aIncentivesAPY X
## vIncentivesAPY X
## priceInUsd X
## aEmissionPerSecond X
## totalLiquidityNormalized X
## totalBorrowsNormalized X
## totalBorrowsVariableNormalized X
## availableLiquidityNormalized X

matic_dataframeDAI = pd.DataFrame(columns = col_names) # Create an empty DataFrame with the column headers
# %%
for date in list_of_dates: # For each date in the list
    print(date) # Show progress as the API is runnin
    request_url = base_url + pool_id + '&date=' + date # Build the Request URL by combining the base, poolID we want, and one date out of the list of dates
    response_data = requests.get(request_url).json() # Make the request and return the data
    while isinstance(response_data, dict) == True: # If we get an error back
        print(json.dumps(response_data, indent=4)) # Dump the error
        time.sleep(5) # Wait 5 seconds to get around rate limiting
        response_data = requests.get(request_url).json() # Try again
    for response in response_data: # For each element in the response
        if response['symbol'] in ['DAI']: # 
            dict_to_append = { # Set the values of the row we want to append to the DataFrame
                'Date' : date, # Date is the date we queried for
                'Symbol' : response['symbol'], # Set symbol in the row to the symbol the API returns
                'Price in ETH': response['price']['priceInEth'], #price in the row to the price in Eth the API returns
                'Deposit Rate': response['liquidityRate'], # Set deposit rate to the deposit rate the API returns
                'aIncentivesAPY' : response['aIncentivesAPY'],# Set deposit rewards to the rate the API returns
                'vIncentivesAPY' : response['vIncentivesAPY'],
                'totalLiquidity' : response['totalLiquidity'],
                'utilizationRate' : response['utilizationRate'],
                'vEmissionPerSecond' : response['vEmissionPerSecond'],
                'totalVariableDebt' : response['totalVariableDebt'],
                'lifetimeDepositorsInterestEarned' : response['lifetimeDepositorsInterestEarned'],
                'availableLiquidity' : response['availableLiquidity'],
                'aEmissionPerSecond' : response['aEmissionPerSecond'],
                'totalLiquidityNormalized' : response['totalLiquidityNormalized'],
                'totalBorrowsNormalized' : response['totalBorrowsNormalized'],
                'totalBorrowsVariableNormalized' : response['totalBorrowsVariableNormalized'],
                'availableLiquidityNormalized' : response['availableLiquidityNormalized'],  
                'USD' : response['referenceItem']['priceInUsd'],  
            }
            matic_dataframeDAI = matic_dataframeDAI.append(dict_to_append, ignore_index = True) # Append the row to the DataFrame
# %%
#--------Once you've imported the data, only ever run from this cell downwards---------

# %%

editing_dataframeDAI = matic_dataframeDAI # Resets the dataframe to the one imported, that way you don't have to rerun the import everytime. Placeholder until Thomas gets the csv writeout completed.
editing_dataframeDAI.head() # Use editing_dataframe as your reference dataframe moving forward until the CSV writing gets completedv


matic_dataframeDAI.head()
matic_dataframeDAI.tail()
# Out:
# 04-01-2021
# 04-02-2021
# 04-03-2021
# 04-04-2021
# 04-05-2021
# 04-06-2021
# 04-07-2021
# 04-08-2021
# 04-09-2021
# 04-10-2021
# 04-11-2021
# 04-12-2021
# 04-13-2021
# 04-14-2021
# 04-15-2021
# 04-16-2021
# 04-17-2021
# 04-18-2021
# 04-19-2021
# 04-20-2021
# 04-21-2021
# 04-22-2021
# 04-23-2021
# 04-24-2021
# 04-25-2021
# 04-26-2021
# 04-27-2021
# 04-28-2021
# 04-29-2021
# 04-30-2021
# 05-01-2021
# 05-02-2021
# 05-03-2021
# 05-04-2021
# 05-05-2021
# 05-06-2021
# 05-07-2021
# 05-08-2021
# 05-09-2021
# 05-10-2021
# 05-11-2021
# 05-12-2021
# 05-13-2021
# 05-14-2021
# 05-15-2021
# 05-16-2021
# 05-17-2021
# 05-18-2021
# 05-19-2021
# 05-20-2021
# 05-21-2021
# 05-22-2021
# 05-23-2021
# 05-24-2021
# 05-25-2021
# 05-26-2021
# 05-27-2021
# 05-28-2021
# 05-29-2021
# 05-30-2021
# 05-31-2021
#           Date Symbol                                   USD priceInETH  \
# 56  05-27-2021    DAI  0.9956712770187201212711974919941452        NaN
# 57  05-28-2021    DAI   0.997200196481542927799478991379578        NaN
# 58  05-29-2021    DAI  0.9955105277360463072713169485596968        NaN
# 59  05-30-2021    DAI   1.000093526178872314814551427938686        NaN
# 60  05-31-2021    DAI   1.001747289043683957353345822069697        NaN
#
#               Deposit Rate          aIncentivesAPY          vIncentivesAPY  \
# 56  0.04586855434487755636  0.04719931152707045079  0.05855857969774942014
# 57  0.02823738600399223435  0.04260015139821745203  0.05379091725227858545
# 58  0.02792599484844207098  0.04054086737439911851  0.05147546611764007022
# 59  0.02821810918562813454   0.0376682286984641962  0.04757888910792282586
# 60  0.02845050208706501763   0.0387945460547909901  0.04880106404499172305
#
#                    totalLiquidity         utilizationRate  vEmissionPerSecond  \
# 56   963109363.450302538057176605  0.80601872126492952301  706597222222222222
# 57   946445540.130170794649057294  0.79195807720517924207  706597222222222222
# 58   950124318.680769432530790372   0.7875764987100566297  706597222222222222
# 59  1056412310.027166881960474506  0.79170046641950056104  706597222222222222
# 60  1080752695.265466633992440773  0.79495287272885465388  706597222222222222
#
#                totalVariableDebt lifetimeDepositorsInterestEarned  \
# 56  776284177.566493103049723327        1853436467623550767637765
# 57  749545190.140907370791769045        1969582723519166055185952
# 58  748295584.245878441132018114        2032784663612396444458098
# 59  836362118.579810049850063759        2101119199983338535678322
# 60  859147459.810735134744716998        2177996909003223027099721
#
#               availableLiquidity  aEmissionPerSecond  \
# 56  186825185.883809435007453278  706597222222222222
# 57  196900349.989263423857288249  706597222222222222
# 58  201828734.434890991398772258  706597222222222222
# 59  220050191.447356832110410747  706597222222222222
# 60  221605235.454731499247723775  706597222222222222
#
#          totalLiquidityNormalized         totalBorrowsNormalized  \
# 56   961064854.088946686533938494  4944777570.086051670737405403
# 57   947917103.117360774405375932  5145657818.767829845205791946
# 58   948709197.324202967615817664  5377735097.030645138907592933
# 59   1053628859.73696684858351953  5669759055.949064052050990993
# 60  1078322358.207537835005821164    5928234469.6463008834261827
#
#    totalBorrowsVariableNormalized  availableLiquidityNormalized  \
# 56  4944777570.086051670737405403  186818767.779401956884127633
# 57  5145657818.767829845205791946  195427238.615597668390240092
# 58  5377735097.030645138907592933  201804638.095135416584587921
# 59  5669759055.949064052050990993  219447472.923104321655018163
# 60    5928234469.6463008834261827  221608951.454017312331725416
#
#           Price in ETH
# 56  0.0003632015750186
# 57  0.0003999728075957
# 58          0.00043615
# 59          0.00043079
# 60          0.00036994

# %%
# TO DO: CREATE A NEW MULTI-LEVEL DATAFRAME FORMATTED LIKE THAT IN 05-APIs/3/Activities/06-Stu_Financial_Forecasting/Solved (YONATHAN AND SAM)
# TO DO: THE INDEX SHOULD BE A DATETIME AND IT SHOULD BE A DATETIME FORMAT (NOT A STRING)
# TO DO: THE 1ST LEVEL SHOULD BE THE COIN SYMBOL (FOR EXAMPLE: TSLA -> USDC... AND THEN ANOTHER SECTION FOR DAI etc..)
# TO DO: THE 2ND LEVEL SHOULD CONTAIN 'close' and 'daily_return'
# TO DO: 'daily_return' SHOULD EQUAL pct_change IN PRICE FOR THAT COIN + WHAT OUR FUNCTION RETURNS BY FEEDING IN THE DEPOSIT RATE FOR A DAY AS THE APY PARAMETER
# TO DO: THIS DATA WILL GET PULLED BY USING A FOR LOOP TO ITERATE THROUGH editing_dataframe
## ['USDC', 'DAI', 'USDT', 'WETH', 'WBTC', 'AAVE', 'WMATIC' ]:
import requests
import json
import pandas as pd
from datetime import datetime, timedelta
import time
import csv
# %%
base_url = 'https://aave-api-v2.aave.com/data/liquidity/v2?poolId=' # This is the base API URL
pool_id = '0xd05e3e715d945b59290df0ae8ef85c1bdb684744' # This is the Pool ID for the Matic Network
# %%
range_of_dates = pd.date_range(start = "2021-04-01",end = (datetime.today() - timedelta(days = 1))).date # List of dates from the start of the AAVE API to yesterday
list_of_dates = []
for date in range_of_dates: # For each date in the list of dates
    list_of_dates.append(date.strftime("%m-%d-%Y")) # Format it correctly for use in the API and append it to a new list
# %%
col_names = ['Date','Symbol', 'USD', 'priceInETH', 'Deposit Rate', 'aIncentivesAPY',
             'vIncentivesAPY','totalLiquidity','utilizationRate','vEmissionPerSecond','totalVariableDebt',
             'lifetimeDepositorsInterestEarned','availableLiquidity','aEmissionPerSecond','totalLiquidityNormalized',
             'totalBorrowsNormalized','totalBorrowsVariableNormalized', 'availableLiquidityNormalized'] 
# These are the fields we want

## totalLiquidity X 
## utilizationRate X
## vEmissionPerSecond X
## totalVariableDebt X
## lifetimeDepositorsInterestEarned X
## availableLiquidity X
## aIncentivesAPY X
## vIncentivesAPY X
## priceInUsd X
## aEmissionPerSecond X
## totalLiquidityNormalized X
## totalBorrowsNormalized X
## totalBorrowsVariableNormalized X
## availableLiquidityNormalized X

matic_dataframeUSDT = pd.DataFrame(columns = col_names) # Create an empty DataFrame with the column headers
# %%
for date in list_of_dates: # For each date in the list
    print(date) # Show progress as the API is runnin
    request_url = base_url + pool_id + '&date=' + date # Build the Request URL by combining the base, poolID we want, and one date out of the list of dates
    response_data = requests.get(request_url).json() # Make the request and return the data
    while isinstance(response_data, dict) == True: # If we get an error back
        print(json.dumps(response_data, indent=4)) # Dump the error
        time.sleep(5) # Wait 5 seconds to get around rate limiting
        response_data = requests.get(request_url).json() # Try again
    for response in response_data: # For each element in the response
        if response['symbol'] in ['USDT']: # 
            dict_to_append = { # Set the values of the row we want to append to the DataFrame
                'Date' : date, # Date is the date we queried for
                'Symbol' : response['symbol'], # Set symbol in the row to the symbol the API returns
                'Price in ETH': response['price']['priceInEth'], #price in the row to the price in Eth the API returns
                'Deposit Rate': response['liquidityRate'], # Set deposit rate to the deposit rate the API returns
                'aIncentivesAPY' : response['aIncentivesAPY'],# Set deposit rewards to the rate the API returns
                'vIncentivesAPY' : response['vIncentivesAPY'],
                'totalLiquidity' : response['totalLiquidity'],
                'utilizationRate' : response['utilizationRate'],
                'vEmissionPerSecond' : response['vEmissionPerSecond'],
                'totalVariableDebt' : response['totalVariableDebt'],
                'lifetimeDepositorsInterestEarned' : response['lifetimeDepositorsInterestEarned'],
                'availableLiquidity' : response['availableLiquidity'],
                'aEmissionPerSecond' : response['aEmissionPerSecond'],
                'totalLiquidityNormalized' : response['totalLiquidityNormalized'],
                'totalBorrowsNormalized' : response['totalBorrowsNormalized'],
                'totalBorrowsVariableNormalized' : response['totalBorrowsVariableNormalized'],
                'availableLiquidityNormalized' : response['availableLiquidityNormalized'],  
                'USD' : response['referenceItem']['priceInUsd'],  
            }
             
            matic_dataframeUSDT = matic_dataframeUSDT.append(dict_to_append, ignore_index = True) # Append the row to the DataFrame
# %%
#--------Once you've imported the data, only ever run from this cell downwards---------

# %%

editing_dataframeUSDT = matic_dataframeUSDT # Resets the dataframe to the one imported, that way you don't have to rerun the import everytime. Placeholder until Thomas gets the csv writeout completed.
editing_dataframeUSDT.head() # Use editing_dataframe as your reference dataframe moving forward until the CSV writing gets completedv


matic_dataframeUSDT.head()
matic_dataframeUSDT.tail()
# Out:
# 04-01-2021
# 04-02-2021
# 04-03-2021
# 04-04-2021
# 04-05-2021
# 04-06-2021
# 04-07-2021
# 04-08-2021
# 04-09-2021
# 04-10-2021
# 04-11-2021
# 04-12-2021
# 04-13-2021
# 04-14-2021
# 04-15-2021
# 04-16-2021
# 04-17-2021
# 04-18-2021
# 04-19-2021
# 04-20-2021
# 04-21-2021
# 04-22-2021
# 04-23-2021
# 04-24-2021
# 04-25-2021
# 04-26-2021
# 04-27-2021
# 04-28-2021
# 04-29-2021
# 04-30-2021
# 05-01-2021
# 05-02-2021
# 05-03-2021
# 05-04-2021
# 05-05-2021
# 05-06-2021
# 05-07-2021
# 05-08-2021
# 05-09-2021
# 05-10-2021
# 05-11-2021
# 05-12-2021
# 05-13-2021
# 05-14-2021
# 05-15-2021
# 05-16-2021
# 05-17-2021
# 05-18-2021
# 05-19-2021
# 05-20-2021
# 05-21-2021
# 05-22-2021
# 05-23-2021
# 05-24-2021
# 05-25-2021
# 05-26-2021
# 05-27-2021
# 05-28-2021
# 05-29-2021
# 05-30-2021
# 05-31-2021
#           Date Symbol                                   USD priceInETH  \
# 56  05-27-2021   USDT  0.9995871238188975290541767266989894        NaN
# 57  05-28-2021   USDT  0.9974150763307502082635646141192334        NaN
# 58  05-29-2021   USDT  0.9979508788737618509336146384319912        NaN
# 59  05-30-2021   USDT   1.000302605994081803918627704022033        NaN
# 60  05-31-2021   USDT  0.9995956333605258679407185814880744        NaN
#
#               Deposit Rate          aIncentivesAPY          vIncentivesAPY  \
# 56  0.03081724179378769935   0.1206638452896764253  0.13753167507414984279
# 57  0.02717746039835738508   0.1019062479598417447  0.12368523710784780507
# 58  0.02611968232153017401  0.09810743377765928252  0.12146206065459159746
# 59  0.02642238620401864939   0.0908734277655571229  0.11185554421657943402
# 60  0.02600337627820652966  0.08801073028826572518  0.10919794143078833507
#
#       totalLiquidity         utilizationRate  vEmissionPerSecond  \
# 56  375257545.416336  0.87735312774036111175  706597222222222222
# 57  392712286.143805  0.82391601732536770476  706597222222222222
# 58  394600150.684584     0.80772080803612279  706597222222222222
# 59  435721894.019576  0.81241773398021424748  706597222222222222
# 60  477414057.376031  0.80597426228999514394  706597222222222222
#
#    totalVariableDebt lifetimeDepositorsInterestEarned availableLiquidity  \
# 56  329233381.179193                    1495331921383    46024164.237143
# 57  323561942.754344                    1536097632267    69150343.389461
# 58  318726752.562128                    1560744474320    75873398.122456
# 59  353988193.784951                    1587930151337    81733700.234625
# 60   384783442.70052                    1618132965395    92630614.675511
#
#     aEmissionPerSecond totalLiquidityNormalized totalBorrowsNormalized  \
# 56  706597222222222222         373558302.303642      1510231120.821278
# 57  706597222222222222         384416337.965746      1544438459.741915
# 58  706597222222222222         392655398.827669      1561054693.157517
# 59  706597222222222222         431513358.059551      1607836250.391063
# 60  706597222222222222          475525599.75954      1650182373.202767
#
#    totalBorrowsVariableNormalized availableLiquidityNormalized  \
# 56              1510231120.821278              46024163.005872
# 57              1544438459.741915               65123663.80612
# 58              1561054693.157517              76862454.178254
# 59              1607836250.391063               80358834.04706
# 60              1650182373.202767              92578459.179747
#
#             Price in ETH
# 56            0.00036463
# 57            0.00040296
# 58  0.000433960483577987
# 59  0.000432940258732457
# 60  0.000369145404883913

# %%
# TO DO: CREATE A NEW MULTI-LEVEL DATAFRAME FORMATTED LIKE THAT IN 05-APIs/3/Activities/06-Stu_Financial_Forecasting/Solved (YONATHAN AND SAM)
# TO DO: THE INDEX SHOULD BE A DATETIME AND IT SHOULD BE A DATETIME FORMAT (NOT A STRING)
# TO DO: THE 1ST LEVEL SHOULD BE THE COIN SYMBOL (FOR EXAMPLE: TSLA -> USDC... AND THEN ANOTHER SECTION FOR DAI etc..)
# TO DO: THE 2ND LEVEL SHOULD CONTAIN 'close' and 'daily_return'
# TO DO: 'daily_return' SHOULD EQUAL pct_change IN PRICE FOR THAT COIN + WHAT OUR FUNCTION RETURNS BY FEEDING IN THE DEPOSIT RATE FOR A DAY AS THE APY PARAMETER
# TO DO: THIS DATA WILL GET PULLED BY USING A FOR LOOP TO ITERATE THROUGH editing_dataframe
## ['USDC', 'DAI', 'USDT', 'WETH', 'WBTC', 'AAVE', 'WMATIC' ]:
import requests
import json
import pandas as pd
from datetime import datetime, timedelta
import time
import csv
# %%
base_url = 'https://aave-api-v2.aave.com/data/liquidity/v2?poolId=' # This is the base API URL
pool_id = '0xd05e3e715d945b59290df0ae8ef85c1bdb684744' # This is the Pool ID for the Matic Network
# %%
range_of_dates = pd.date_range(start = "2021-04-01",end = (datetime.today() - timedelta(days = 1))).date # List of dates from the start of the AAVE API to yesterday
list_of_dates = []
for date in range_of_dates: # For each date in the list of dates
    list_of_dates.append(date.strftime("%m-%d-%Y")) # Format it correctly for use in the API and append it to a new list
# %%
col_names = ['Date','Symbol', 'USD', 'priceInETH', 'Deposit Rate', 'aIncentivesAPY',
             'vIncentivesAPY','totalLiquidity','utilizationRate','vEmissionPerSecond','totalVariableDebt',
             'lifetimeDepositorsInterestEarned','availableLiquidity','aEmissionPerSecond','totalLiquidityNormalized',
             'totalBorrowsNormalized','totalBorrowsVariableNormalized', 'availableLiquidityNormalized'] 
# These are the fields we want

## totalLiquidity X 
## utilizationRate X
## vEmissionPerSecond X
## totalVariableDebt X
## lifetimeDepositorsInterestEarned X
## availableLiquidity X
## aIncentivesAPY X
## vIncentivesAPY X
## priceInUsd X
## aEmissionPerSecond X
## totalLiquidityNormalized X
## totalBorrowsNormalized X
## totalBorrowsVariableNormalized X
## availableLiquidityNormalized X

matic_dataframeUSDC = pd.DataFrame(columns = col_names) # Create an empty DataFrame with the column headers
# %%
for date in list_of_dates: # For each date in the list
    print(date) # Show progress as the API is runnin
    request_url = base_url + pool_id + '&date=' + date # Build the Request URL by combining the base, poolID we want, and one date out of the list of dates
    response_data = requests.get(request_url).json() # Make the request and return the data
    while isinstance(response_data, dict) == True: # If we get an error back
        print(json.dumps(response_data, indent=4)) # Dump the error
        time.sleep(5) # Wait 5 seconds to get around rate limiting
        response_data = requests.get(request_url).json() # Try again
    for response in response_data: # For each element in the response
        if response['symbol'] in ['USDC']: # 
            dict_to_append = { # Set the values of the row we want to append to the DataFrame
                'Date' : date, # Date is the date we queried for
                'Symbol' : response['symbol'], # Set symbol in the row to the symbol the API returns
                'Price in ETH': response['price']['priceInEth'], #price in the row to the price in Eth the API returns
                'Deposit Rate': response['liquidityRate'], # Set deposit rate to the deposit rate the API returns
                'aIncentivesAPY' : response['aIncentivesAPY'],# Set deposit rewards to the rate the API returns
                'vIncentivesAPY' : response['vIncentivesAPY'],
                'totalLiquidity' : response['totalLiquidity'],
                'utilizationRate' : response['utilizationRate'],
                'vEmissionPerSecond' : response['vEmissionPerSecond'],
                'totalVariableDebt' : response['totalVariableDebt'],
                'lifetimeDepositorsInterestEarned' : response['lifetimeDepositorsInterestEarned'],
                'availableLiquidity' : response['availableLiquidity'],
                'aEmissionPerSecond' : response['aEmissionPerSecond'],
                'totalLiquidityNormalized' : response['totalLiquidityNormalized'],
                'totalBorrowsNormalized' : response['totalBorrowsNormalized'],
                'totalBorrowsVariableNormalized' : response['totalBorrowsVariableNormalized'],
                'availableLiquidityNormalized' : response['availableLiquidityNormalized'],  
                'USD' : response['referenceItem']['priceInUsd'],  
            }
             
            matic_dataframeUSDC = matic_dataframeUSDC.append(dict_to_append, ignore_index = True) # Append the row to the DataFrame
# %%
#--------Once you've imported the data, only ever run from this cell downwards---------

# %%

editing_dataframeUSDC = matic_dataframeUSDC # Resets the dataframe to the one imported, that way you don't have to rerun the import everytime. Placeholder until Thomas gets the csv writeout completed.
editing_dataframeUSDC.head() # Use editing_dataframe as your reference dataframe moving forward until the CSV writing gets completedv


matic_dataframeUSDC.head()
matic_dataframeUSDC.tail()
# Out:
# 04-01-2021
# 04-02-2021
# 04-03-2021
# 04-04-2021
# 04-05-2021
# 04-06-2021
# 04-07-2021
# 04-08-2021
# 04-09-2021
# 04-10-2021
# 04-11-2021
# 04-12-2021
# 04-13-2021
# 04-14-2021
# 04-15-2021
# 04-16-2021
# 04-17-2021
# 04-18-2021
# 04-19-2021
# 04-20-2021
# 04-21-2021
# 04-22-2021
# 04-23-2021
# 04-24-2021
# 04-25-2021
# 04-26-2021
# 04-27-2021
# 04-28-2021
# 04-29-2021
# 04-30-2021
# 05-01-2021
# 05-02-2021
# 05-03-2021
# 05-04-2021
# 05-05-2021
# 05-06-2021
# 05-07-2021
# 05-08-2021
# 05-09-2021
# 05-10-2021
# 05-11-2021
# 05-12-2021
# 05-13-2021
# 05-14-2021
# 05-15-2021
# 05-16-2021
# 05-17-2021
# 05-18-2021
# 05-19-2021
# 05-20-2021
# 05-21-2021
# 05-22-2021
# 05-23-2021
# 05-24-2021
# 05-25-2021
# 05-26-2021
# 05-27-2021
# 05-28-2021
# 05-29-2021
# 05-30-2021
# 05-31-2021
#           Date Symbol                                   USD priceInETH  \
# 56  05-27-2021   USDC  0.9950090295952254261731179132892663        NaN
# 57  05-28-2021   USDC  0.9993978166036986086775673365036644        NaN
# 58  05-29-2021   USDC  0.9993843958511708487381886878761861        NaN
# 59  05-30-2021   USDC   1.000541227798946804348951804142267        NaN
# 60  05-31-2021   USDC   1.003567344964746131355585043641672        NaN
#
#               Deposit Rate          aIncentivesAPY          vIncentivesAPY  \
# 56  0.01843703347499713729  0.02818638962261456741  0.04152176468715774399
# 57  0.01776447153306270472  0.02509358826566359747   0.0376596302050611928
# 58  0.01734667470320874488  0.02367703164778302488  0.03595903875424041746
# 59  0.01704158829782214035   0.0239593612932230538  0.03671203030204112483
# 60  0.01711818895061435095  0.02383841279607656512  0.03644472808902661272
#
#        totalLiquidity         utilizationRate  vEmissionPerSecond  \
# 56   1613841112.76403   0.6788340966474464093  706597222222222222
# 57  1601819388.203679  0.66632593387205362014  706597222222222222
# 58  1627908894.154291  0.65844450986585244256  706597222222222222
# 59  1663727352.448968  0.65262969920492125756  706597222222222222
# 60  1755623236.149561  0.65409769933924222337  706597222222222222
#
#     totalVariableDebt lifetimeDepositorsInterestEarned availableLiquidity  \
# 56   1095530373.91568                    1733789404836    518310738.84835
# 57  1067333799.739178                    1840198461012   534485588.464501
# 58  1071887673.917684                    1906400879191   556021220.236607
# 59   1085797881.58777                    1973741427994   577929470.861198
# 60  1148349119.671943                    2046098739735   607274116.477618
#
#     aEmissionPerSecond totalLiquidityNormalized totalBorrowsNormalized  \
# 56  706597222222222222        1611882865.448294      6408901550.100228
# 57  706597222222222222        1602222694.954139      6593642861.053471
# 58  706597222222222222        1612041294.401274      6751519342.087292
# 59  706597222222222222        1659568732.660976      6897555341.183591
# 60  706597222222222222         1753266276.68544      7177861274.714017
#
#    totalBorrowsVariableNormalized availableLiquidityNormalized  \
# 56              6408901550.100228              518310738.84835
# 57              6593642861.053471             537661279.604052
# 58              6751519342.087292             556207622.924143
# 59              6897555341.183591             576554824.960848
# 60              7177861274.714017             607223207.251032
#
#             Price in ETH
# 56            0.00036296
# 57             0.0004012
# 58           0.000435865
# 59  0.000430047940349819
# 60    0.0003706121370697

# %%
# TO DO: CREATE A NEW MULTI-LEVEL DATAFRAME FORMATTED LIKE THAT IN 05-APIs/3/Activities/06-Stu_Financial_Forecasting/Solved (YONATHAN AND SAM)
# TO DO: THE INDEX SHOULD BE A DATETIME AND IT SHOULD BE A DATETIME FORMAT (NOT A STRING)
# TO DO: THE 1ST LEVEL SHOULD BE THE COIN SYMBOL (FOR EXAMPLE: TSLA -> USDC... AND THEN ANOTHER SECTION FOR DAI etc..)
# TO DO: THE 2ND LEVEL SHOULD CONTAIN 'close' and 'daily_return'
# TO DO: 'daily_return' SHOULD EQUAL pct_change IN PRICE FOR THAT COIN + WHAT OUR FUNCTION RETURNS BY FEEDING IN THE DEPOSIT RATE FOR A DAY AS THE APY PARAMETER
# TO DO: THIS DATA WILL GET PULLED BY USING A FOR LOOP TO ITERATE THROUGH editing_dataframe
## ['USDC', 'DAI', 'USDT', 'WETH', 'WBTC', 'AAVE', 'WMATIC' ]:
import requests
import json
import pandas as pd
from datetime import datetime, timedelta
import time
import csv
# %%
base_url = 'https://aave-api-v2.aave.com/data/liquidity/v2?poolId=' # This is the base API URL
pool_id = '0xd05e3e715d945b59290df0ae8ef85c1bdb684744' # This is the Pool ID for the Matic Network
# %%
range_of_dates = pd.date_range(start = "2021-04-01",end = (datetime.today() - timedelta(days = 1))).date # List of dates from the start of the AAVE API to yesterday
list_of_dates = []
for date in range_of_dates: # For each date in the list of dates
    list_of_dates.append(date.strftime("%m-%d-%Y")) # Format it correctly for use in the API and append it to a new list
# %%
col_names = ['Date','Symbol', 'USD', 'priceInETH', 'Deposit Rate', 'aIncentivesAPY',
             'vIncentivesAPY','totalLiquidity','utilizationRate','vEmissionPerSecond','totalVariableDebt',
             'lifetimeDepositorsInterestEarned','availableLiquidity','aEmissionPerSecond','totalLiquidityNormalized',
             'totalBorrowsNormalized','totalBorrowsVariableNormalized', 'availableLiquidityNormalized'] 
# These are the fields we want

## totalLiquidity X 
## utilizationRate X
## vEmissionPerSecond X
## totalVariableDebt X
## lifetimeDepositorsInterestEarned X
## availableLiquidity X
## aIncentivesAPY X
## vIncentivesAPY X
## priceInUsd X
## aEmissionPerSecond X
## totalLiquidityNormalized X
## totalBorrowsNormalized X
## totalBorrowsVariableNormalized X
## availableLiquidityNormalized X

matic_dataframeWMATIC = pd.DataFrame(columns = col_names) # Create an empty DataFrame with the column headers
# %%
for date in list_of_dates: # For each date in the list
    print(date) # Show progress as the API is runnin
    request_url = base_url + pool_id + '&date=' + date # Build the Request URL by combining the base, poolID we want, and one date out of the list of dates
    response_data = requests.get(request_url).json() # Make the request and return the data
    while isinstance(response_data, dict) == True: # If we get an error back
        print(json.dumps(response_data, indent=4)) # Dump the error
        time.sleep(5) # Wait 5 seconds to get around rate limiting
        response_data = requests.get(request_url).json() # Try again
    for response in response_data: # For each element in the response
        if response['symbol'] in ['WMATIC']: # 
            dict_to_append = { # Set the values of the row we want to append to the DataFrame
                'Date' : date, # Date is the date we queried for
                'Symbol' : response['symbol'], # Set symbol in the row to the symbol the API returns
                'Price in ETH': response['price']['priceInEth'], #price in the row to the price in Eth the API returns
                'Deposit Rate': response['liquidityRate'], # Set deposit rate to the deposit rate the API returns
                'aIncentivesAPY' : response['aIncentivesAPY'],# Set deposit rewards to the rate the API returns
                'vIncentivesAPY' : response['vIncentivesAPY'],
                'totalLiquidity' : response['totalLiquidity'],
                'utilizationRate' : response['utilizationRate'],
                'vEmissionPerSecond' : response['vEmissionPerSecond'],
                'totalVariableDebt' : response['totalVariableDebt'],
                'lifetimeDepositorsInterestEarned' : response['lifetimeDepositorsInterestEarned'],
                'availableLiquidity' : response['availableLiquidity'],
                'aEmissionPerSecond' : response['aEmissionPerSecond'],
                'totalLiquidityNormalized' : response['totalLiquidityNormalized'],
                'totalBorrowsNormalized' : response['totalBorrowsNormalized'],
                'totalBorrowsVariableNormalized' : response['totalBorrowsVariableNormalized'],
                'availableLiquidityNormalized' : response['availableLiquidityNormalized'],  
                'USD' : response['referenceItem']['priceInUsd'],  
            }
             
            matic_dataframeWMATIC = matic_dataframeWMATIC.append(dict_to_append, ignore_index = True) # Append the row to the DataFrame
# %%
#--------Once you've imported the data, only ever run from this cell downwards---------

# %%

editing_dataframeWMATIC = matic_dataframeWMATIC # Resets the dataframe to the one imported, that way you don't have to rerun the import everytime. Placeholder until Thomas gets the csv writeout completed.
editing_dataframeWMATIC.head() # Use editing_dataframe as your reference dataframe moving forward until the CSV writing gets completedv


matic_dataframeWMATIC.head()
matic_dataframeWMATIC.tail()
# Out:
# 04-01-2021
# 04-02-2021
# 04-03-2021
# 04-04-2021
# 04-05-2021
# 04-06-2021
# 04-07-2021
# 04-08-2021
# 04-09-2021
# 04-10-2021
# 04-11-2021
# 04-12-2021
# 04-13-2021
# 04-14-2021
# 04-15-2021
# 04-16-2021
# 04-17-2021
# 04-18-2021
# 04-19-2021
# 04-20-2021
# 04-21-2021
# 04-22-2021
# 04-23-2021
# 04-24-2021
# 04-25-2021
# 04-26-2021
# 04-27-2021
# 04-28-2021
# 04-29-2021
# 04-30-2021
# 05-01-2021
# 05-02-2021
# 05-03-2021
# 05-04-2021
# 05-05-2021
# 05-06-2021
# 05-07-2021
# 05-08-2021
# 05-09-2021
# 05-10-2021
# 05-11-2021
# 05-12-2021
# 05-13-2021
# 05-14-2021
# 05-15-2021
# 05-16-2021
# 05-17-2021
# 05-18-2021
# 05-19-2021
# 05-20-2021
# 05-21-2021
# 05-22-2021
# 05-23-2021
# 05-24-2021
# 05-25-2021
# 05-26-2021
# 05-27-2021
# 05-28-2021
# 05-29-2021
# 05-30-2021
# 05-31-2021
#           Date  Symbol                                  USD priceInETH  \
# 56  05-27-2021  WMATIC  2.031181419354072672102793160574882        NaN
# 57  05-28-2021  WMATIC  1.827975656916716164392276665911089        NaN
# 58  05-29-2021  WMATIC  1.684747775919844624759300935332803        NaN
# 59  05-30-2021  WMATIC  1.845821582330807481714530655097761        NaN
# 60  05-31-2021  WMATIC  1.884849352768436418089574521294399        NaN
#
#               Deposit Rate          aIncentivesAPY          vIncentivesAPY  \
# 56  0.02347943522641765745  0.05700227048386848079  0.13131940187275040045
# 57  0.02450457407959066074   0.0579599141600357501  0.13071172812151483861
# 58  0.02374404232788989248  0.05858976682152500082  0.13423267744596640378
# 59  0.03757961869116731257  0.05822492089462635218  0.12776809880007993714
# 60   0.0299877276836189178  0.05771630075773422804   0.1276860048763917322
#
#                   totalLiquidity         utilizationRate  vEmissionPerSecond  \
# 56   390918639.04449405273772769  0.43407348549382031142  706597222222222222
# 57  384459679.123621661368311943  0.44341785540585846256  706597222222222222
# 58   380326654.44596834347919406  0.43647916391379095988  706597222222222222
# 59  382709837.258989696241514777  0.45570781315085142517  706597222222222222
# 60  386082436.113405109194053838  0.45201743772629835617  706597222222222222
#
#                totalVariableDebt lifetimeDepositorsInterestEarned  \
# 56  169687416.194544167607081435        1053179477107825252351791
# 57  170476286.407020811202588915        1086919284058888539615620
# 58  166004660.146705549920728629        1108965374785973489711278
# 59  174403863.008612433439720705        1131696911209854594739566
# 60  174515993.523108657496478299        1163675907625009531373730
#
#               availableLiquidity  aEmissionPerSecond  \
# 56  221231222.849949885130646255  706597222222222222
# 57  213983392.716600850165723028  706597222222222222
# 58  214321994.299262793558465431  706597222222222222
# 59  208305974.250377262801794072  706597222222222222
# 60  211566442.590296451697575539  706597222222222222
#
#         totalLiquidityNormalized         totalBorrowsNormalized  \
# 56   389600764.10229188703148765  5422906135.937125838978829849
# 57  381848150.094368667876191343  5942221238.359057847856381913
# 58  376420597.031144568431332828   6296003133.26312482373607423
# 59  379396891.874103617257692547  6821388107.891367535788330163
# 60  384658154.833697640687001969  7432398246.136495490407315392
#
#    totalBorrowsVariableNormalized  availableLiquidityNormalized  \
# 56  5422906135.937125838978829849  221232382.705406779620096691
# 57  5942221238.359057847856381913  214901719.655825793914491556
# 58   6296003133.26312482373607423  212582872.339793678143393978
# 59  6821388107.891367535788330163  209563520.293600331564958397
# 60  7432398246.136495490407315392  211597951.127547258588489352
#
#             Price in ETH
# 56  0.000740935595598229
# 57    0.0007237002213259
# 58  0.000753929634612191
# 59             0.0007693
# 60  0.000696064942914708

# %%
# TO DO: CREATE A NEW MULTI-LEVEL DATAFRAME FORMATTED LIKE THAT IN 05-APIs/3/Activities/06-Stu_Financial_Forecasting/Solved (YONATHAN AND SAM)
# TO DO: THE INDEX SHOULD BE A DATETIME AND IT SHOULD BE A DATETIME FORMAT (NOT A STRING)
# TO DO: THE 1ST LEVEL SHOULD BE THE COIN SYMBOL (FOR EXAMPLE: TSLA -> USDC... AND THEN ANOTHER SECTION FOR DAI etc..)
# TO DO: THE 2ND LEVEL SHOULD CONTAIN 'close' and 'daily_return'
# TO DO: 'daily_return' SHOULD EQUAL pct_change IN PRICE FOR THAT COIN + WHAT OUR FUNCTION RETURNS BY FEEDING IN THE DEPOSIT RATE FOR A DAY AS THE APY PARAMETER
# TO DO: THIS DATA WILL GET PULLED BY USING A FOR LOOP TO ITERATE THROUGH editing_dataframe
## ['USDC', 'DAI', 'USDT', 'WETH', 'WBTC', 'AAVE', 'WMATIC' ]:
import requests
import json
import pandas as pd
from datetime import datetime, timedelta
import time
import csv
# %%
base_url = 'https://aave-api-v2.aave.com/data/liquidity/v2?poolId=' # This is the base API URL
pool_id = '0xd05e3e715d945b59290df0ae8ef85c1bdb684744' # This is the Pool ID for the Matic Network
# %%
range_of_dates = pd.date_range(start = "2021-04-01",end = (datetime.today() - timedelta(days = 1))).date # List of dates from the start of the AAVE API to yesterday
list_of_dates = []
for date in range_of_dates: # For each date in the list of dates
    list_of_dates.append(date.strftime("%m-%d-%Y")) # Format it correctly for use in the API and append it to a new list
# %%
col_names = ['Date','Symbol', 'USD', 'priceInETH', 'Deposit Rate', 'aIncentivesAPY',
             'vIncentivesAPY','totalLiquidity','utilizationRate','vEmissionPerSecond','totalVariableDebt',
             'lifetimeDepositorsInterestEarned','availableLiquidity','aEmissionPerSecond','totalLiquidityNormalized',
             'totalBorrowsNormalized','totalBorrowsVariableNormalized', 'availableLiquidityNormalized'] 
# These are the fields we want

## totalLiquidity X 
## utilizationRate X
## vEmissionPerSecond X
## totalVariableDebt X
## lifetimeDepositorsInterestEarned X
## availableLiquidity X
## aIncentivesAPY X
## vIncentivesAPY X
## priceInUsd X
## aEmissionPerSecond X
## totalLiquidityNormalized X
## totalBorrowsNormalized X
## totalBorrowsVariableNormalized X
## availableLiquidityNormalized X

matic_dataframeWETH = pd.DataFrame(columns = col_names) # Create an empty DataFrame with the column headers
# %%
for date in list_of_dates: # For each date in the list
    print(date) # Show progress as the API is runnin
    request_url = base_url + pool_id + '&date=' + date # Build the Request URL by combining the base, poolID we want, and one date out of the list of dates
    response_data = requests.get(request_url).json() # Make the request and return the data
    while isinstance(response_data, dict) == True: # If we get an error back
        print(json.dumps(response_data, indent=4)) # Dump the error
        time.sleep(5) # Wait 5 seconds to get around rate limiting
        response_data = requests.get(request_url).json() # Try again
    for response in response_data: # For each element in the response
        if response['symbol'] in ['WETH']: # 
            dict_to_append = { # Set the values of the row we want to append to the DataFrame
                'Date' : date, # Date is the date we queried for
                'Symbol' : response['symbol'], # Set symbol in the row to the symbol the API returns
                'Price in ETH': response['price']['priceInEth'], #price in the row to the price in Eth the API returns
                'Deposit Rate': response['liquidityRate'], # Set deposit rate to the deposit rate the API returns
                'aIncentivesAPY' : response['aIncentivesAPY'],# Set deposit rewards to the rate the API returns
                'vIncentivesAPY' : response['vIncentivesAPY'],
                'totalLiquidity' : response['totalLiquidity'],
                'utilizationRate' : response['utilizationRate'],
                'vEmissionPerSecond' : response['vEmissionPerSecond'],
                'totalVariableDebt' : response['totalVariableDebt'],
                'lifetimeDepositorsInterestEarned' : response['lifetimeDepositorsInterestEarned'],
                'availableLiquidity' : response['availableLiquidity'],
                'aEmissionPerSecond' : response['aEmissionPerSecond'],
                'totalLiquidityNormalized' : response['totalLiquidityNormalized'],
                'totalBorrowsNormalized' : response['totalBorrowsNormalized'],
                'totalBorrowsVariableNormalized' : response['totalBorrowsVariableNormalized'],
                'availableLiquidityNormalized' : response['availableLiquidityNormalized'],  
                'USD' : response['referenceItem']['priceInUsd'],  
            }
             
            matic_dataframeWETH = matic_dataframeWETH.append(dict_to_append, ignore_index = True) # Append the row to the DataFrame
# %%
#--------Once you've imported the data, only ever run from this cell downwards---------

# %%

editing_dataframeWETH = matic_dataframeWETH # Resets the dataframe to the one imported, that way you don't have to rerun the import everytime. Placeholder until Thomas gets the csv writeout completed.
editing_dataframeWETH.head() # Use editing_dataframe as your reference dataframe moving forward until the CSV writing gets completedv


matic_dataframeWETH.head()
matic_dataframeWETH.tail()
# Out:
# 04-01-2021
# 04-02-2021
# 04-03-2021
# 04-04-2021
# 04-05-2021
# 04-06-2021
# 04-07-2021
# 04-08-2021
# 04-09-2021
# 04-10-2021
# 04-11-2021
# 04-12-2021
# 04-13-2021
# 04-14-2021
# 04-15-2021
# 04-16-2021
# 04-17-2021
# 04-18-2021
# 04-19-2021
# 04-20-2021
# 04-21-2021
# 04-22-2021
# 04-23-2021
# 04-24-2021
# 04-25-2021
# 04-26-2021
# 04-27-2021
# 04-28-2021
# 04-29-2021
# 04-30-2021
# 05-01-2021
# 05-02-2021
# 05-03-2021
# 05-04-2021
# 05-05-2021
# 05-06-2021
# 05-07-2021
# 05-08-2021
# 05-09-2021
# 05-10-2021
# 05-11-2021
# 05-12-2021
# 05-13-2021
# 05-14-2021
# 05-15-2021
# 05-16-2021
# 05-17-2021
# 05-18-2021
# 05-19-2021
# 05-20-2021
# 05-21-2021
# 05-22-2021
# 05-23-2021
# 05-24-2021
# 05-25-2021
# 05-26-2021
# 05-27-2021
# 05-28-2021
# 05-29-2021
# 05-30-2021
# 05-31-2021
#           Date Symbol                                  USD priceInETH  \
# 56  05-27-2021   WETH  2741.373786630001725184918209414994        NaN
# 57  05-28-2021   WETH  2417.975942620000504881368761501172        NaN
# 58  05-29-2021   WETH  2276.347807650004222020106383284652        NaN
# 59  05-30-2021   WETH  2386.218048650004303241001202342636        NaN
# 60  05-31-2021   WETH  2707.864218640006372258598210709025        NaN
#
#               Deposit Rate          aIncentivesAPY          vIncentivesAPY  \
# 56  0.01383649282164498404   0.0206306704440384082  0.05837731075984042347
# 57  0.01443929738889622653  0.01983250370715320373  0.05493657320989479074
# 58  0.01410135969237275665   0.0202162167829486014  0.05666601420642897629
# 59  0.01371448542782849034  0.01996819733041506513  0.05675426887536392234
# 60  0.01449768643791884075   0.0173749174133163574  0.04803088704515634507
#
#                totalLiquidity         utilizationRate  vEmissionPerSecond  \
# 56   800286.79413980070390086  0.35340220670512440189  706597222222222222
# 57   813129.45631992396954421  0.36100729529269423176  706597222222222222
# 58  831016.144654824468339062  0.35676087450412198217  706597222222222222
# 59  858490.325458120390072518  0.35183604204763045024  706597222222222222
# 60  892700.020969115773055778  0.36174467061125250974  706597222222222222
#
#             totalVariableDebt lifetimeDepositorsInterestEarned  \
# 56  282823.119045975188213867            566459774256573921683
# 57  293545.665748874708387146            608118256886897169999
# 58  296474.046494099111696182            635876301552887087329
# 59  302047.838245367195532933            663363556453076302718
# 60  322929.475040130993774032            695315233185156390869
#
#            availableLiquidity  aEmissionPerSecond   totalLiquidityNormalized  \
# 56  517463.675093825515686993  706597222222222222  799652.112708312070991104
# 57  519583.790571049261157064  706597222222222222  809470.649337766339210795
# 58   534542.09816072535664288  706597222222222222  811477.686198686738107853
# 59  556442.487212753194539585  706597222222222222   851201.81703432954238197
# 60  569770.545928984779281746  706597222222222222  891950.741388990887311423
#
#         totalBorrowsNormalized totalBorrowsVariableNormalized  \
# 56  2766809.678531097118768638     2766809.678531097118768638
# 57  3135268.754578192107874952     3135268.754578192107874952
# 58  3605850.005651778340483875     3605850.005651778340483875
# 59  4131804.233856589102096663     4131804.233856589102096663
# 60  5171930.996176593540660964     5171930.996176593540660964
#
#    availableLiquidityNormalized Price in ETH
# 56    517463.669662260343093188            1
# 57    517878.417402935214190083            1
# 58    517795.330822462350901855            1
# 59    554418.614885578309821802            1
# 60    569800.631172095280591145            1

# %%
# TO DO: CREATE A NEW MULTI-LEVEL DATAFRAME FORMATTED LIKE THAT IN 05-APIs/3/Activities/06-Stu_Financial_Forecasting/Solved (YONATHAN AND SAM)
# TO DO: THE INDEX SHOULD BE A DATETIME AND IT SHOULD BE A DATETIME FORMAT (NOT A STRING)
# TO DO: THE 1ST LEVEL SHOULD BE THE COIN SYMBOL (FOR EXAMPLE: TSLA -> USDC... AND THEN ANOTHER SECTION FOR DAI etc..)
# TO DO: THE 2ND LEVEL SHOULD CONTAIN 'close' and 'daily_return'
# TO DO: 'daily_return' SHOULD EQUAL pct_change IN PRICE FOR THAT COIN + WHAT OUR FUNCTION RETURNS BY FEEDING IN THE DEPOSIT RATE FOR A DAY AS THE APY PARAMETER
# TO DO: THIS DATA WILL GET PULLED BY USING A FOR LOOP TO ITERATE THROUGH editing_dataframe
## ['USDC', 'DAI', 'USDT', 'WETH', 'WBTC', 'AAVE', 'WMATIC' ]:
import requests
import json
import pandas as pd
from datetime import datetime, timedelta
import time
import csv
# %%
base_url = 'https://aave-api-v2.aave.com/data/liquidity/v2?poolId=' # This is the base API URL
pool_id = '0xd05e3e715d945b59290df0ae8ef85c1bdb684744' # This is the Pool ID for the Matic Network
# %%
range_of_dates = pd.date_range(start = "2021-04-01",end = (datetime.today() - timedelta(days = 1))).date # List of dates from the start of the AAVE API to yesterday
list_of_dates = []
for date in range_of_dates: # For each date in the list of dates
    list_of_dates.append(date.strftime("%m-%d-%Y")) # Format it correctly for use in the API and append it to a new list
# %%
col_names = ['Date','Symbol', 'USD', 'priceInETH', 'Deposit Rate', 'aIncentivesAPY',
             'vIncentivesAPY','totalLiquidity','utilizationRate','vEmissionPerSecond','totalVariableDebt',
             'lifetimeDepositorsInterestEarned','availableLiquidity','aEmissionPerSecond','totalLiquidityNormalized',
             'totalBorrowsNormalized','totalBorrowsVariableNormalized', 'availableLiquidityNormalized'] 
# These are the fields we want

## totalLiquidity X 
## utilizationRate X
## vEmissionPerSecond X
## totalVariableDebt X
## lifetimeDepositorsInterestEarned X
## availableLiquidity X
## aIncentivesAPY X
## vIncentivesAPY X
## priceInUsd X
## aEmissionPerSecond X
## totalLiquidityNormalized X
## totalBorrowsNormalized X
## totalBorrowsVariableNormalized X
## availableLiquidityNormalized X

matic_dataframeAAVE = pd.DataFrame(columns = col_names) # Create an empty DataFrame with the column headers
# %%
for date in list_of_dates: # For each date in the list
    print(date) # Show progress as the API is runnin
    request_url = base_url + pool_id + '&date=' + date # Build the Request URL by combining the base, poolID we want, and one date out of the list of dates
    response_data = requests.get(request_url).json() # Make the request and return the data
    while isinstance(response_data, dict) == True: # If we get an error back
        print(json.dumps(response_data, indent=4)) # Dump the error
        time.sleep(5) # Wait 5 seconds to get around rate limiting
        response_data = requests.get(request_url).json() # Try again
    for response in response_data: # For each element in the response
        if response['symbol'] in ['AAVE']: # 
            dict_to_append = { # Set the values of the row we want to append to the DataFrame
                'Date' : date, # Date is the date we queried for
                'Symbol' : response['symbol'], # Set symbol in the row to the symbol the API returns
                'Price in ETH': response['price']['priceInEth'], #price in the row to the price in Eth the API returns
                'Deposit Rate': response['liquidityRate'], # Set deposit rate to the deposit rate the API returns
                'aIncentivesAPY' : response['aIncentivesAPY'],# Set deposit rewards to the rate the API returns
                'vIncentivesAPY' : response['vIncentivesAPY'],
                'totalLiquidity' : response['totalLiquidity'],
                'utilizationRate' : response['utilizationRate'],
                'vEmissionPerSecond' : response['vEmissionPerSecond'],
                'totalVariableDebt' : response['totalVariableDebt'],
                'lifetimeDepositorsInterestEarned' : response['lifetimeDepositorsInterestEarned'],
                'availableLiquidity' : response['availableLiquidity'],
                'aEmissionPerSecond' : response['aEmissionPerSecond'],
                'totalLiquidityNormalized' : response['totalLiquidityNormalized'],
                'totalBorrowsNormalized' : response['totalBorrowsNormalized'],
                'totalBorrowsVariableNormalized' : response['totalBorrowsVariableNormalized'],
                'availableLiquidityNormalized' : response['availableLiquidityNormalized'],  
                'USD' : response['referenceItem']['priceInUsd'],  
            }
             
            matic_dataframeAAVE = matic_dataframeAAVE.append(dict_to_append, ignore_index = True) # Append the row to the DataFrame
# %%
#--------Once you've imported the data, only ever run from this cell downwards---------

# %%

editing_dataframeAAVE = matic_dataframeAAVE # Resets the dataframe to the one imported, that way you don't have to rerun the import everytime. Placeholder until Thomas gets the csv writeout completed.
editing_dataframeAAVE.head() # Use editing_dataframe as your reference dataframe moving forward until the CSV writing gets completedv


matic_dataframeAAVE.head()
matic_dataframeAAVE.tail()
# Out:
# 04-01-2021
# 04-02-2021
# 04-03-2021
# 04-04-2021
# 04-05-2021
# 04-06-2021
# 04-07-2021
# 04-08-2021
# 04-09-2021
# 04-10-2021
# 04-11-2021
# 04-12-2021
# 04-13-2021
# 04-14-2021
# 04-15-2021
# 04-16-2021
# 04-17-2021
# 04-18-2021
# 04-19-2021
# 04-20-2021
# 04-21-2021
# 04-22-2021
# 04-23-2021
# 04-24-2021
# 04-25-2021
# 04-26-2021
# 04-27-2021
# 04-28-2021
# 04-29-2021
# 04-30-2021
# 05-01-2021
# 05-02-2021
# 05-03-2021
# 05-04-2021
# 05-05-2021
# 05-06-2021
# 05-07-2021
# 05-08-2021
# 05-09-2021
# 05-10-2021
# 05-11-2021
# 05-12-2021
# 05-13-2021
# 05-14-2021
# 05-15-2021
# 05-16-2021
# 05-17-2021
# 05-18-2021
# 05-19-2021
# 05-20-2021
# 05-21-2021
# 05-22-2021
# 05-23-2021
# 05-24-2021
# 05-25-2021
# 05-26-2021
# 05-27-2021
# 05-28-2021
# 05-29-2021
# 05-30-2021
# 05-31-2021
#           Date Symbol                                  USD priceInETH  \
# 56  05-27-2021   AAVE  373.3274098351188729401676425454784        NaN
# 57  05-28-2021   AAVE  318.3259834203330221519019005724556        NaN
# 58  05-29-2021   AAVE   297.063388898325550973623883018647        NaN
# 59  05-30-2021   AAVE  324.0700053935588521833063602354562        NaN
# 60  05-31-2021   AAVE  385.1539607334534575603045618376077        NaN
#
#    Deposit Rate          aIncentivesAPY vIncentivesAPY  \
# 56            0  0.22808316157627940988              0
# 57            0  0.23128607298667831785              0
# 58            0  0.23879629727905844794              0
# 59            0  0.22461488154391256231              0
# 60            0  0.19028839765082636447              0
#
#                totalLiquidity utilizationRate vEmissionPerSecond  \
# 56  531550.029205393081248028               0                  0
# 57  535471.810849574494757194               0                  0
# 58    540245.2963256144748164               0                  0
# 59  561728.898307706127190136               0                  0
# 60  573071.090264791812258224               0                  0
#
#    totalVariableDebt lifetimeDepositorsInterestEarned  \
# 56                 0                                0
# 57                 0                                0
# 58                 0                                0
# 59                 0                                0
# 60                 0                                0
#
#            availableLiquidity  aEmissionPerSecond   totalLiquidityNormalized  \
# 56  531550.029205393081248028  706597222222222222  531550.007798375753762999
# 57  535471.810849574494757194  706597222222222222  534188.265579409589291022
# 58    540245.2963256144748164  706597222222222222  536406.359689073160487666
# 59  561728.898307706127190136  706597222222222222  561436.542397319664661437
# 60  573071.090264791812258224  706597222222222222  573070.905327959208076709
#
#    totalBorrowsNormalized totalBorrowsVariableNormalized  \
# 56                  0.005                          0.005
# 57                  0.005                          0.005
# 58                  0.005                          0.005
# 59                  0.005                          0.005
# 60                  0.005                          0.005
#
#    availableLiquidityNormalized         Price in ETH
# 56    531550.029205393081248028            0.1361826
# 57    534188.288405095948596519  0.13021204000000003
# 58    536406.382729461296117976           0.13022392
# 59    561436.565437707800291747  0.13586543132804832
# 60    573070.930981808453144504           0.14223533

# %%
# TO DO: CREATE A NEW MULTI-LEVEL DATAFRAME FORMATTED LIKE THAT IN 05-APIs/3/Activities/06-Stu_Financial_Forecasting/Solved (YONATHAN AND SAM)
# TO DO: THE INDEX SHOULD BE A DATETIME AND IT SHOULD BE A DATETIME FORMAT (NOT A STRING)
# TO DO: THE 1ST LEVEL SHOULD BE THE COIN SYMBOL (FOR EXAMPLE: TSLA -> USDC... AND THEN ANOTHER SECTION FOR DAI etc..)
# TO DO: THE 2ND LEVEL SHOULD CONTAIN 'close' and 'daily_return'
# TO DO: 'daily_return' SHOULD EQUAL pct_change IN PRICE FOR THAT COIN + WHAT OUR FUNCTION RETURNS BY FEEDING IN THE DEPOSIT RATE FOR A DAY AS THE APY PARAMETER
# TO DO: THIS DATA WILL GET PULLED BY USING A FOR LOOP TO ITERATE THROUGH editing_dataframe
## ['USDC', 'DAI', 'USDT', 'WETH', 'WBTC', 'AAVE', 'WMATIC' ]:
import requests
import json
import pandas as pd
from datetime import datetime, timedelta
import time
import csv
# %%
base_url = 'https://aave-api-v2.aave.com/data/liquidity/v2?poolId=' # This is the base API URL
pool_id = '0xd05e3e715d945b59290df0ae8ef85c1bdb684744' # This is the Pool ID for the Matic Network
# %%
range_of_dates = pd.date_range(start = "2021-04-01",end = (datetime.today() - timedelta(days = 1))).date # List of dates from the start of the AAVE API to yesterday
list_of_dates = []
for date in range_of_dates: # For each date in the list of dates
    list_of_dates.append(date.strftime("%m-%d-%Y")) # Format it correctly for use in the API and append it to a new list
# %%
col_names = ['Date','Symbol', 'USD', 'priceInETH', 'Deposit Rate', 'aIncentivesAPY',
             'vIncentivesAPY','totalLiquidity','utilizationRate','vEmissionPerSecond','totalVariableDebt',
             'lifetimeDepositorsInterestEarned','availableLiquidity','aEmissionPerSecond','totalLiquidityNormalized',
             'totalBorrowsNormalized','totalBorrowsVariableNormalized', 'availableLiquidityNormalized'] 
# These are the fields we want

## totalLiquidity X 
## utilizationRate X
## vEmissionPerSecond X
## totalVariableDebt X
## lifetimeDepositorsInterestEarned X
## availableLiquidity X
## aIncentivesAPY X
## vIncentivesAPY X
## priceInUsd X
## aEmissionPerSecond X
## totalLiquidityNormalized X
## totalBorrowsNormalized X
## totalBorrowsVariableNormalized X
## availableLiquidityNormalized X

matic_dataframeWBTC = pd.DataFrame(columns = col_names) # Create an empty DataFrame with the column headers
# %%
for date in list_of_dates: # For each date in the list
    print(date) # Show progress as the API is runnin
    request_url = base_url + pool_id + '&date=' + date # Build the Request URL by combining the base, poolID we want, and one date out of the list of dates
    response_data = requests.get(request_url).json() # Make the request and return the data
    while isinstance(response_data, dict) == True: # If we get an error back
        print(json.dumps(response_data, indent=4)) # Dump the error
        time.sleep(5) # Wait 5 seconds to get around rate limiting
        response_data = requests.get(request_url).json() # Try again
    for response in response_data: # For each element in the response
        if response['symbol'] in ['WBTC']: # 
            dict_to_append = { # Set the values of the row we want to append to the DataFrame
                'Date' : date, # Date is the date we queried for
                'Symbol' : response['symbol'], # Set symbol in the row to the symbol the API returns
                'Price in ETH': response['price']['priceInEth'], #price in the row to the price in Eth the API returns
                'Deposit Rate': response['liquidityRate'], # Set deposit rate to the deposit rate the API returns
                'aIncentivesAPY' : response['aIncentivesAPY'],# Set deposit rewards to the rate the API returns
                'vIncentivesAPY' : response['vIncentivesAPY'],
                'totalLiquidity' : response['totalLiquidity'],
                'utilizationRate' : response['utilizationRate'],
                'vEmissionPerSecond' : response['vEmissionPerSecond'],
                'totalVariableDebt' : response['totalVariableDebt'],
                'lifetimeDepositorsInterestEarned' : response['lifetimeDepositorsInterestEarned'],
                'availableLiquidity' : response['availableLiquidity'],
                'aEmissionPerSecond' : response['aEmissionPerSecond'],
                'totalLiquidityNormalized' : response['totalLiquidityNormalized'],
                'totalBorrowsNormalized' : response['totalBorrowsNormalized'],
                'totalBorrowsVariableNormalized' : response['totalBorrowsVariableNormalized'],
                'availableLiquidityNormalized' : response['availableLiquidityNormalized'],  
                'USD' : response['referenceItem']['priceInUsd'],  
            }
             
            matic_dataframeWBTC = matic_dataframeWBTC.append(dict_to_append, ignore_index = True) # Append the row to the DataFrame
# %%
#--------Once you've imported the data, only ever run from this cell downwards---------

# %%

editing_dataframeWBTC = matic_dataframeWBTC # Resets the dataframe to the one imported, that way you don't have to rerun the import everytime. Placeholder until Thomas gets the csv writeout completed.
editing_dataframeWBTC.head() # Use editing_dataframe as your reference dataframe moving forward until the CSV writing gets completedv


matic_dataframeWBTC.head()
matic_dataframeWBTC.tail()
# Out:
# 04-01-2021
# 04-02-2021
# 04-03-2021
# 04-04-2021
# 04-05-2021
# 04-06-2021
# 04-07-2021
# 04-08-2021
# 04-09-2021
# 04-10-2021
# 04-11-2021
# 04-12-2021
# 04-13-2021
# 04-14-2021
# 04-15-2021
# 04-16-2021
# 04-17-2021
# 04-18-2021
# 04-19-2021
# 04-20-2021
# 04-21-2021
# 04-22-2021
# 04-23-2021
# 04-24-2021
# 04-25-2021
# 04-26-2021
# 04-27-2021
# 04-28-2021
# 04-29-2021
# 04-30-2021
# 05-01-2021
# 05-02-2021
# 05-03-2021
# 05-04-2021
# 05-05-2021
# 05-06-2021
# 05-07-2021
# 05-08-2021
# 05-09-2021
# 05-10-2021
# 05-11-2021
# 05-12-2021
# 05-13-2021
# 05-14-2021
# 05-15-2021
# 05-16-2021
# 05-17-2021
# 05-18-2021
# 05-19-2021
# 05-20-2021
# 05-21-2021
# 05-22-2021
# 05-23-2021
# 05-24-2021
# 05-25-2021
# 05-26-2021
# 05-27-2021
# 05-28-2021
# 05-29-2021
# 05-30-2021
# 05-31-2021
#           Date Symbol                                  USD priceInETH  \
# 56  05-27-2021   WBTC   38347.3416931999388214692008413322        NaN
# 57  05-28-2021   WBTC  35612.28803212335875240361725400684        NaN
# 58  05-29-2021   WBTC  34327.32493936206366806320425993255        NaN
# 59  05-30-2021   WBTC  35552.59937834089814309482118656257        NaN
# 60  05-31-2021   WBTC  37464.26972995350205410588343953269        NaN
#
#               Deposit Rate          aIncentivesAPY          vIncentivesAPY  \
# 56  0.02013376061582877097  0.04093515512942475356  0.09054435517859404418
# 57  0.02028562705194179374  0.03730145303551268993  0.08220072486183896424
# 58  0.02067408434208561526  0.03601842789278567637  0.07862372275536769633
# 59  0.02166274889445263856   0.0363641321262057532  0.07754560395192677007
# 60  0.02279253383302122342     0.03463879368822898  0.07201236397706571478
#
#     totalLiquidity         utilizationRate  vEmissionPerSecond  \
# 56  28833.37922818  0.45210057599595560996  706597222222222222
# 57  29918.76354933  0.45378496477017800846  706597222222222222
# 58  30668.59991522  0.45811145326779471538  706597222222222222
# 59  31317.01057724  0.46893866670700185075  706597222222222222
# 60  32364.96538505  0.48101175652642983391  706597222222222222
#
#    totalVariableDebt lifetimeDepositorsInterestEarned availableLiquidity  \
# 56    13035.58735697                       2496887984     15797.79187121
# 57     13576.6850632                       2714808103     16342.07848613
# 58    14049.63687685                       2861721970     16618.96303837
# 59    14685.75718534                       3015835992      16631.2533919
# 60    15567.92884978                       3196576609     16797.03653527
#
#     aEmissionPerSecond totalLiquidityNormalized totalBorrowsNormalized  \
# 56  706597222222222222           28802.14647685         56606.68796149
# 57  706597222222222222           29761.23407842         67255.73397646
# 58  706597222222222222           30414.17219891         89095.92478203
# 59  706597222222222222           30542.77482339        108876.25373164
# 60  706597222222222222           32324.97568733         134818.6976983
#
#    totalBorrowsVariableNormalized availableLiquidityNormalized  \
# 56                 56606.68796149               15797.79187121
# 57                 67255.73397646               16293.73702307
# 58                 89095.92478203               16542.28179745
# 59                108876.25373164               16398.65709142
# 60                 134818.6976983               16797.03653527
#
#           Price in ETH
# 56        13.988366665
# 57               14.45
# 58   15.20864924829015
# 59          15.0529195
# 60  13.835357575192415
